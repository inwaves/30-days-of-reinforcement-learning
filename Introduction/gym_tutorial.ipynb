# %% [markdown]
# # Getting Started with Gym
# ---
#
# *The gym library is a collection of test problems — environments — that you can use to work out your reinforcement learning algorithms. These environments have a shared interface, allowing you to write general algorithms.*

# %%
import gym

# %%
env = gym.make("CartPole-v0") # Or MountainCar-v0, MsPacman-v0
env.reset()

for _ in range(1000):
    env.render()
    env.step(env.action_space.sample()) # Take a random action
    
env.close()
# Out:
# /Users/inwaves/anaconda3/envs/my_first_env/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-27abe7f8e435> in <module>
#       3
#       4 for _ in range(1000):
# ----> 5     env.render()
#       6     env.step(env.action_space.sample()) # Take a random action
#       7
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     211         self.poletrans.set_rotation(-x[2])
#     212
# --> 213         return self.viewer.render(return_rgb_array=mode == 'rgb_array')
#     214
#     215     def close(self):
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py in render(self, return_rgb_array)
#     125             arr = arr.reshape(buffer.height, buffer.width, 4)
#     126             arr = arr[::-1,:,0:3]
# --> 127         self.window.flip()
#     128         self.onetime_geoms = []
#     129         return arr if return_rgb_array else self.isopen
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/pyglet/window/cocoa/__init__.py in flip(self)
#     294         self.draw_mouse_cursor()
#     295         if self.context:
# --> 296             self.context.flip()
#     297
#     298     def dispatch_events(self):
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/pyglet/gl/cocoa.py in flip(self)
#     333
#     334     def flip(self):
# --> 335         self._nscontext.flushBuffer()
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py in __call__(self, *args)
#     790     def __call__(self, *args):
#     791         """Call the method with the given arguments."""
# --> 792         return self.method(self.objc_id, *args)
#     793
#     794 ######################################################################
#
# ~/anaconda3/envs/my_first_env/lib/python3.8/site-packages/pyglet/libs/darwin/cocoapy/runtime.py in __call__(self, objc_id, *args)
#     760         f = self.get_callable()
#     761         try:
# --> 762             result = f(objc_id, self.selector, *args)
#     763             # Convert result to python type if it is a instance or class pointer.
#     764             if self.restype == ObjCInstance:
#
# KeyboardInterrupt:

# %% [markdown]
# `step` returns four values:
# - `observation` is an object whose content is environment-specific
# - `reward` is a `float`
# - `done` tells you whether you need to `reset` the environment (episode has ended)
# - `info` contains diagnostic information

# %%
env = gym.make("CartPole-v0")

try:
    for i_episode in range(20):
        observation = env.reset()
        for t in range(100):
            env.render()
            print("Observation[{}]: {}".format(i_episode, observation))
            action = env.action_space.sample()
            observation, reward, done, info = env.step(action) # See above.
            if done:
                print("Episode finished after {} timesteps".format(t+1))
                break
finally:
    env.close()
# Out:
# Observation[0]: [-0.00965659 -0.02293371  0.04553614  0.01350137]
# Observation[0]: [-0.01011526  0.17150662  0.04580617 -0.26447379]
# Observation[0]: [-0.00668513 -0.02423819  0.04051669  0.04229774]
# Observation[0]: [-0.00716989  0.17028005  0.04136265 -0.23733151]
# Observation[0]: [-0.00376429 -0.02540767  0.03661602  0.06810616]
# Observation[0]: [-0.00427244  0.16917071  0.03797814 -0.21280307]
# Observation[0]: [-0.00088903  0.36372968  0.03372208 -0.49326819]
# Observation[0]: [ 0.00638556  0.16814874  0.02385671 -0.19015116]
# Observation[0]: [ 0.00974854 -0.02730624  0.02005369  0.10996109]
# Observation[0]: [ 0.00920241 -0.22270973  0.02225291  0.40890278]
# Observation[0]: [ 0.00474822 -0.02791024  0.03043097  0.1233177 ]
# Observation[0]: [ 0.00419001 -0.22345465  0.03289732  0.42544384]
# Observation[0]: [-2.79079155e-04 -4.19026767e-01  4.14061985e-02  7.28313356e-01]
# Observation[0]: [-0.00865961 -0.61469591  0.05597247  1.03373545]
# Observation[0]: [-0.02095353 -0.42036119  0.07664717  0.75913719]
# Observation[0]: [-0.02936076 -0.22637434  0.09182992  0.49152344]
# Observation[0]: [-0.03388824 -0.42266349  0.10166039  0.81167666]
# Observation[0]: [-0.04234151 -0.22907014  0.11789392  0.5526226 ]
# Observation[0]: [-0.04692292 -0.42563321  0.12894637  0.88000114]
# Observation[0]: [-0.05543558 -0.23247666  0.1465464   0.63047697]
# Observation[0]: [-0.06008511 -0.42930662  0.15915593  0.96548786]
# Observation[0]: [-0.06867125 -0.62616681  0.17846569  1.30364065]
# Observation[0]: [-0.08119458 -0.43369979  0.2045385   1.07171631]
# Episode finished after 23 timesteps
# Observation[1]: [-0.04824269 -0.01452895  0.0028694   0.03454896]
# Observation[1]: [-0.04853327 -0.20969194  0.00356037  0.32813583]
# Observation[1]: [-0.05272711 -0.01462085  0.01012309  0.03657781]
# Observation[1]: [-0.05301953 -0.2098865   0.01085465  0.3324374 ]
# Observation[1]: [-0.05721726 -0.40516125  0.0175034   0.62852349]
# Observation[1]: [-0.06532048 -0.2102879   0.03007387  0.34140396]
# Observation[1]: [-0.06952624 -0.01560645  0.03690194  0.05835422]
# Observation[1]: [-0.06983837  0.1789675   0.03806903 -0.22246129]
# Observation[1]: [-0.06625902 -0.01667732  0.0336198   0.0819829 ]
# Observation[1]: [-0.06659257 -0.21226467  0.03525946  0.3850805 ]
# Observation[1]: [-0.07083786 -0.01766057  0.04296107  0.10371992]
# Observation[1]: [-0.07119107 -0.21337102  0.04503547  0.4096414 ]
# Observation[1]: [-0.07545849 -0.01891554  0.0532283   0.13148987]
# Observation[1]: [-0.0758368   0.17540513  0.05585809 -0.14393658]
# Observation[1]: [-0.0723287   0.36968448  0.05297936 -0.41848735]
# Observation[1]: [-0.06493501  0.56401722  0.04460962 -0.69400882]
# Observation[1]: [-0.05365467  0.36830579  0.03072944 -0.38762285]
# Observation[1]: [-0.04628855  0.17276142  0.02297698 -0.08541174]
# Observation[1]: [-0.04283332 -0.02268223  0.02126875  0.21443099]
# Observation[1]: [-0.04328697  0.1721293   0.02555737 -0.07146767]
# Observation[1]: [-0.03984438  0.3668757   0.02412801 -0.35597883]
# Observation[1]: [-0.03250687  0.56164644  0.01700844 -0.64095695]
# Observation[1]: [-0.02127394  0.36629156  0.0041893  -0.34296678]
# Observation[1]: [-0.01394811  0.17111026 -0.00267004 -0.04896575]
# Observation[1]: [-0.0105259  -0.0239733  -0.00364935  0.24287356]
# Observation[1]: [-0.01100537 -0.21904293  0.00120812  0.53440316]
# Observation[1]: [-0.01538623 -0.41418185  0.01189618  0.82746651]
# Observation[1]: [-0.02366986 -0.21922457  0.02844551  0.53854867]
# Observation[1]: [-0.02805435 -0.02451382  0.03921649  0.25496256]
# Observation[1]: [-0.02854463 -0.22017313  0.04431574  0.55975256]
# Observation[1]: [-0.03294809 -0.41588815  0.05551079  0.86606143]
# Observation[1]: [-0.04126586 -0.61171986  0.07283202  1.17566832]
# Observation[1]: [-0.05350025 -0.41761582  0.09634538  0.90667782]
# Observation[1]: [-0.06185257 -0.22392107  0.11447894  0.64576486]
# Observation[1]: [-0.06633099 -0.03056474  0.12739424  0.39121215]
# Observation[1]: [-0.06694229  0.16254079  0.13521848  0.14125384]
# Observation[1]: [-0.06369147 -0.03423256  0.13804356  0.47335281]
# Observation[1]: [-0.06437612 -0.23100649  0.14751061  0.80616191]
# Observation[1]: [-0.06899625 -0.42780915  0.16363385  1.14137099]
# Observation[1]: [-0.07755243 -0.23515932  0.18646127  0.90415037]
# Observation[1]: [-0.08225562 -0.43225038  0.20454428  1.24916503]
# Episode finished after 41 timesteps
# Observation[2]: [-0.04731017 -0.03443951 -0.03017092  0.04829164]
# Observation[2]: [-0.04799896 -0.22911613 -0.02920508  0.33130477]
# Observation[2]: [-0.05258128 -0.42381046 -0.02257899  0.61463665]
# Observation[2]: [-0.06105749 -0.61860976 -0.01028626  0.90012346]
# Observation[2]: [-0.07342969 -0.81359082  0.00771621  1.18955548]
# Observation[2]: [-0.0897015  -0.61856973  0.03150732  0.89930108]
# Observation[2]: [-0.1020729  -0.81410419  0.04949334  1.20171882]
# Observation[2]: [-0.11835498 -1.00983003  0.07352772  1.50949318]
# Observation[2]: [-0.13855158 -1.20576201  0.10371758  1.82419472]
# Observation[2]: [-0.16266682 -1.01193278  0.14020148  1.56545162]
# Observation[2]: [-0.18290548 -1.20842431  0.17151051  1.89838124]
# Episode finished after 11 timesteps
# Observation[3]: [-0.00637593  0.03899883 -0.04793792 -0.01653479]
# Observation[3]: [-0.00559595 -0.15540403 -0.04826862  0.26064614]
# Observation[3]: [-0.00870403  0.04037254 -0.04305569 -0.04686214]
# Observation[3]: [-0.00789658  0.23608459 -0.04399294 -0.35281261]
# Observation[3]: [-0.00317489  0.04161493 -0.05104919 -0.07432011]
# Observation[3]: [-0.00234259 -0.15273942 -0.05253559  0.20182969]
# Observation[3]: [-0.00539738 -0.3470722  -0.048499    0.47748832]
# Observation[3]: [-0.01233882 -0.15130024 -0.03894923  0.16992256]
# Observation[3]: [-0.01536483  0.04435693 -0.03555078 -0.13478879]
# Observation[3]: [-0.01447769  0.23996959 -0.03824656 -0.4384721 ]
# Observation[3]: [-0.0096783   0.43561142 -0.047016   -0.74296197]
# Observation[3]: [-9.66066792e-04  6.31349707e-01 -6.18752375e-02 -1.05006257e+00]
# Observation[3]: [ 0.01166093  0.4371007  -0.08287649 -0.77742637]
# Observation[3]: [ 0.02040294  0.63325862 -0.09842502 -1.09499114]
# Observation[3]: [ 0.03306811  0.43956104 -0.12032484 -0.83474122]
# Observation[3]: [ 0.04185933  0.24627029 -0.13701966 -0.58219163]
# Observation[3]: [ 0.04678474  0.44301904 -0.1486635  -0.91470656]
# Observation[3]: [ 0.05564512  0.25018651 -0.16695763 -0.67219445]
# Observation[3]: [ 0.06064885  0.05773037 -0.18040152 -0.43638224]
# Observation[3]: [ 0.06180346  0.25488602 -0.18912916 -0.7800673 ]
# Observation[3]: [ 0.06690118  0.45203466 -0.20473051 -1.12579009]
# Episode finished after 21 timesteps
# Observation[4]: [-0.04718607  0.04409372 -0.00895519  0.02995397]
# Observation[4]: [-0.0463042   0.23934295 -0.00835611 -0.26554091]
# Observation[4]: [-0.04151734  0.43458316 -0.01366693 -0.56084768]
# Observation[4]: [-0.03282567  0.62989423 -0.02488388 -0.85780487]
# Observation[4]: [-0.02022779  0.43511996 -0.04203998 -0.57304902]
# Observation[4]: [-0.01152539  0.63080536 -0.05350096 -0.87867389]
# Observation[4]: [ 1.09071684e-03  8.26611880e-01 -7.10744385e-02 -1.18768520e+00]
# Observation[4]: [ 0.01762295  0.63247972 -0.09482814 -0.91810045]
# Observation[4]: [ 0.03027255  0.43875882 -0.11319015 -0.65666234]
# Observation[4]: [ 0.03904773  0.63525931 -0.1263234  -0.98273381]
# Observation[4]: [ 0.05175291  0.83182671 -0.14597807 -1.31227585]
# Observation[4]: [ 0.06838945  0.6388231  -0.17222359 -1.06861489]
# Observation[4]: [ 0.08116591  0.44634524 -0.19359589 -0.83455312]
# Episode finished after 13 timesteps
# Observation[5]: [-0.02281967 -0.04709172 -0.01319275 -0.03229051]
# Observation[5]: [-0.0237615  -0.24202202 -0.01383856  0.25620094]
# Observation[5]: [-0.02860194 -0.43694369 -0.00871454  0.54448703]
# Observation[5]: [-0.03734082 -0.24170037  0.0021752   0.24907113]
# Observation[5]: [-0.04217482 -0.04660955  0.00715662 -0.0429249 ]
# Observation[5]: [-0.04310701 -0.24183339  0.00629812  0.25200739]
# Observation[5]: [-0.04794368 -0.04680193  0.01133827 -0.03868235]
# Observation[5]: [-0.04887972 -0.24208462  0.01056462  0.25755623]
# Observation[5]: [-0.05372141 -0.4373558   0.01571575  0.55355259]
# Observation[5]: [-0.06246853 -0.63269487  0.0267868   0.85114526]
# Observation[5]: [-0.07512243 -0.82817161  0.0438097   1.15212955]
# Observation[5]: [-0.09168586 -0.63364773  0.06685229  0.87349964]
# Observation[5]: [-0.10435881 -0.43949536  0.08432229  0.60256155]
# Observation[5]: [-0.11314872 -0.24564777  0.09637352  0.33758466]
# Observation[5]: [-0.11806168 -0.05201989  0.10312521  0.07678058]
# Observation[5]: [-0.11910207 -0.24845744  0.10466082  0.40013658]
# Observation[5]: [-0.12407122 -0.05496374  0.11266355  0.14219835]
# Observation[5]: [-0.1251705   0.13837949  0.11550752 -0.1129248 ]
# Observation[5]: [-0.12240291  0.33167316  0.11324903 -0.36704952]
# Observation[5]: [-0.11576944  0.13513941  0.10590803 -0.04091324]
# Observation[5]: [-0.11306666  0.32859581  0.10508977 -0.29839314]
# Observation[5]: [-0.10649474  0.13214507  0.09912191  0.02549685]
# Observation[5]: [-0.10385184  0.32571611  0.09963184 -0.23434035]
# Observation[5]: [-0.09733752  0.12932224  0.09494504  0.08803287]
# Observation[5]: [-0.09475107  0.32296408  0.09670569 -0.17324976]
# Observation[5]: [-0.08829179  0.51657851  0.0932407  -0.43392728]
# Observation[5]: [-0.07796022  0.32026871  0.08456215 -0.1133686 ]
# Observation[5]: [-0.07155485  0.12404327  0.08229478  0.20474947]
# Observation[5]: [-0.06907398  0.31789783  0.08638977 -0.06088091]
# Observation[5]: [-0.06271602  0.51168173  0.08517215 -0.32510574]
# Observation[5]: [-0.05248239  0.31545687  0.07867004 -0.00682505]
# Observation[5]: [-0.04617325  0.11929997  0.07853354  0.3096054 ]
# Observation[5]: [-0.04378725  0.31322027  0.08472564  0.04268663]
# Observation[5]: [-0.03752285  0.50703153  0.08557938 -0.22210789]
# Observation[5]: [-0.02738222  0.31079724  0.08113722  0.09629594]
# Observation[5]: [-0.02116627  0.1146118   0.08306314  0.41343417]
# Observation[5]: [-0.01887404 -0.08158328  0.09133182  0.73110462]
# Observation[5]: [-0.0205057  -0.27784077  0.10595391  1.05107814]
# Observation[5]: [-0.02606252 -0.08427143  0.12697548  0.7934446 ]
# Observation[5]: [-0.02774795  0.10890013  0.14284437  0.54325053]
# Observation[5]: [-0.02556994 -0.08790983  0.15370938  0.8773123 ]
# Observation[5]: [-0.02732814  0.10482665  0.17125563  0.63662896]
# Observation[5]: [-0.02523161  0.29719886  0.1839882   0.4023952 ]
# Observation[5]: [-0.01928763  0.48929972  0.19203611  0.17289523]
# Observation[5]: [-0.00950163  0.68122881  0.19549401 -0.053594  ]
# Observation[5]: [ 0.00412294  0.8730888   0.19442213 -0.27879228]
# Observation[5]: [0.02158472 0.67580176 0.18884629 0.06836347]
# Observation[5]: [ 0.03510075  0.86778512  0.19021356 -0.1593004 ]
# Observation[5]: [ 0.05245645  1.05974704  0.18702755 -0.38646373]
# Observation[5]: [ 0.0736514   0.86253095  0.17929827 -0.04113231]
# Observation[5]: [0.09090201 0.66535152 0.17847563 0.30232709]
# Observation[5]: [0.10420905 0.46819448 0.18452217 0.64555875]
# Observation[5]: [0.11357293 0.6603311  0.19743334 0.41618856]
# Observation[5]: [0.12677956 0.46303926 0.20575712 0.76404625]
# Episode finished after 54 timesteps
# Observation[6]: [ 0.00870742  0.02550265 -0.01732676  0.04544284]
# Observation[6]: [ 0.00921747  0.22086871 -0.0164179  -0.25265608]
# Observation[6]: [ 0.01363485  0.025985   -0.02147102  0.03480345]
# Observation[6]: [ 0.01415455  0.22140816 -0.02077496 -0.26457573]
# Observation[6]: [ 0.01858271  0.41682038 -0.02606647 -0.56373821]
# Observation[6]: [ 0.02691912  0.22207369 -0.03734123 -0.27938008]
# Observation[6]: [ 0.03136059  0.41770788 -0.04292884 -0.58360257]
# Observation[6]: [ 0.03971475  0.22321279 -0.05460089 -0.30474591]
# Observation[6]: [ 0.044179    0.41906861 -0.06069581 -0.61413652]
# Observation[6]: [ 0.05256038  0.61498383 -0.07297854 -0.92530182]
# Observation[6]: [ 0.06486005  0.42091937 -0.09148457 -0.65641661]
# Observation[6]: [ 0.07327844  0.61718777 -0.1046129  -0.97644704]
# Observation[6]: [ 0.0856222   0.81354531 -0.12414185 -1.30007325]
# Observation[6]: [ 0.1018931   1.01000482 -0.15014331 -1.62889871]
# Observation[6]: [ 0.1220932   0.81693281 -0.18272128 -1.38652535]
# Episode finished after 15 timesteps
# Observation[7]: [-0.02390431  0.00726734 -0.03709715 -0.02861174]
# Observation[7]: [-0.02375896 -0.18730352 -0.03766938  0.25213969]
# Observation[7]: [-0.02750504  0.00833552 -0.03262659 -0.05218286]
# Observation[7]: [-0.02733833 -0.18630379 -0.03367025  0.23003019]
# Observation[7]: [-0.0310644   0.00928272 -0.02906964 -0.07308047]
# Observation[7]: [-0.03087875  0.2048091  -0.03053125 -0.3747914 ]
# Observation[7]: [-0.02678256  0.40035113 -0.03802708 -0.67694253]
# Observation[7]: [-0.01877554  0.2057776  -0.05156593 -0.3964705 ]
# Observation[7]: [-0.01465999  0.01142374 -0.05949534 -0.1204809 ]
# Observation[7]: [-0.01443151 -0.18279757 -0.06190496  0.1528543 ]
# Observation[7]: [-0.01808747  0.01315364 -0.05884787 -0.15869793]
# Observation[7]: [-0.01782439  0.20906658 -0.06202183 -0.46934993]
# Observation[7]: [-0.01364306  0.0148731  -0.07140883 -0.19684252]
# Observation[7]: [-0.0133456  -0.17915865 -0.07534568  0.072487  ]
# Observation[7]: [-0.01692877  0.01695809 -0.07389594 -0.24298416]
# Observation[7]: [-0.01658961  0.2130535  -0.07875562 -0.55803019]
# Observation[7]: [-0.01232854  0.40918753 -0.08991623 -0.87444954]
# Observation[7]: [-0.00414479  0.60540931 -0.10740522 -1.19399295]
# Observation[7]: [ 0.0079634   0.41182957 -0.13128508 -0.93681301]
# Observation[7]: [ 0.01619999  0.21869896 -0.15002134 -0.68809712]
# Observation[7]: [ 0.02057397  0.02594242 -0.16378328 -0.44615091]
# Observation[7]: [ 0.02109281 -0.16652967 -0.1727063  -0.20924372]
# Observation[7]: [ 0.01776222 -0.35881555 -0.17689117  0.02437063]
# Observation[7]: [ 0.01058591 -0.55101783 -0.17640376  0.25644001]
# Observation[7]: [-0.00043445 -0.35387366 -0.17127496 -0.08628122]
# Observation[7]: [-0.00751192 -0.15676334 -0.17300058 -0.42772961]
# Observation[7]: [-0.01064719 -0.34906719 -0.18155518 -0.19418854]
# Observation[7]: [-0.01762853 -0.15187536 -0.18543895 -0.53819921]
# Observation[7]: [-0.02066604  0.04530293 -0.19620293 -0.88310296]
# Episode finished after 29 timesteps
# Observation[8]: [-0.00396587 -0.00301494  0.02640972  0.03884015]
# Observation[8]: [-0.00402616 -0.19850546  0.02718652  0.33973722]
# Observation[8]: [-0.00799627 -0.00378068  0.03398127  0.05574984]
# Observation[8]: [-0.00807189  0.19083798  0.03509627 -0.22602103]
# Observation[8]: [-0.00425513 -0.00476752  0.03057585  0.07752271]
# Observation[8]: [-0.00435048 -0.20031415  0.0321263   0.37969346]
# Observation[8]: [-0.00835676 -0.39587724  0.03972017  0.68233023]
# Observation[8]: [-0.01627431 -0.20132875  0.05336677  0.40241232]
# Observation[8]: [-0.02030088 -0.00700273  0.06141502  0.12702067]
# Observation[8]: [-0.02044094 -0.20294828  0.06395543  0.43842952]
# Observation[8]: [-0.0244999  -0.39891439  0.07272402  0.7505678 ]
# Observation[8]: [-0.03247819 -0.20486676  0.08773538  0.48162775]
# Observation[8]: [-0.03657552 -0.40111044  0.09736793  0.80062218]
# Observation[8]: [-0.04459773 -0.2074492   0.11338038  0.54008721]
# Observation[8]: [-0.04874672 -0.40396704  0.12418212  0.86623376]
# Observation[8]: [-0.05682606 -0.60054034  0.1415068   1.19523887]
# Observation[8]: [-0.06883686 -0.4075052   0.16541157  0.95004464]
# Observation[8]: [-0.07698697 -0.21494947  0.18441247  0.71356296]
# Observation[8]: [-0.08128596 -0.02279438  0.19868373  0.48412804]
# Observation[8]: [-0.08174185  0.16905081  0.20836629  0.26005091]
# Episode finished after 20 timesteps
# Observation[9]: [-0.04850308 -0.0227369  -0.01473058  0.04252537]
# Observation[9]: [-0.04895781 -0.21764455 -0.01388008  0.3305245 ]
# Observation[9]: [-0.05331071 -0.4125662  -0.00726958  0.6187982 ]
# Observation[9]: [-0.06156203 -0.60758586  0.00510638  0.90918272]
# Observation[9]: [-0.07371375 -0.4125334   0.02329003  0.61810911]
# Observation[9]: [-0.08196441 -0.21774439  0.03565222  0.33285148]
# Observation[9]: [-0.0863193  -0.02314755  0.04230925  0.05162124]
# Observation[9]: [-0.08678225 -0.21884982  0.04334167  0.35734716]
# Observation[9]: [-0.09115925 -0.4145603   0.05048861  0.66337565]
# Observation[9]: [-0.09945046 -0.22017575  0.06375613  0.38700773]
# Observation[9]: [-0.10385397 -0.41614207  0.07149628  0.69909158]
# Observation[9]: [-0.11217681 -0.22208039  0.08547811  0.42974474]
# Observation[9]: [-0.11661842 -0.02826634  0.09407301  0.16518507]
# Observation[9]: [-0.11718375 -0.22460023  0.09737671  0.48600043]
# Observation[9]: [-0.12167575 -0.0309775   0.10709672  0.22552576]
# Observation[9]: [-0.1222953   0.16246382  0.11160723 -0.0315475 ]
# Observation[9]: [-0.11904602  0.35582303  0.11097628 -0.28703734]
# Observation[9]: [-0.11192956  0.5492018   0.10523554 -0.54276104]
# Observation[9]: [-0.10094553  0.74269961  0.09438031 -0.80051989]
# Observation[9]: [-0.08609154  0.5464186   0.07836992 -0.47970207]
# Observation[9]: [-0.07516316  0.74035181  0.06877588 -0.74669184]
# Observation[9]: [-0.06035613  0.54435173  0.05384204 -0.4331826 ]
# Observation[9]: [-0.04946909  0.73867167  0.04517839 -0.70841821]
# Observation[9]: [-0.03469566  0.542954    0.03101002 -0.40186333]
# Observation[9]: [-0.02383658  0.7376227   0.02297276 -0.68461051]
# Observation[9]: [-0.00908413  0.54218945  0.00928055 -0.38478459]
# Observation[9]: [ 0.00175966  0.73717843  0.00158485 -0.67452701]
# Observation[9]: [ 0.01650323  0.93227832 -0.01190569 -0.96671053]
# Observation[9]: [ 0.0351488   1.12755812 -0.0312399  -1.26310966]
# Observation[9]: [ 0.05769996  1.32306523 -0.05650209 -1.56541027]
# Observation[9]: [ 0.08416127  1.12866223 -0.0878103  -1.2908739 ]
# Observation[9]: [ 0.10673451  1.32478411 -0.11362777 -1.60970634]
# Observation[9]: [ 0.13323019  1.52105041 -0.1458219  -1.93554202]
# Observation[9]: [ 0.1636512   1.71739971 -0.18453274 -2.26966   ]
# Episode finished after 34 timesteps
# Observation[10]: [ 0.01865757 -0.03766379 -0.03862796 -0.00868107]
# Observation[10]: [ 0.01790429  0.15799024 -0.03880158 -0.31329698]
# Observation[10]: [ 0.0210641   0.35364284 -0.04506752 -0.6179598 ]
# Observation[10]: [ 0.02813695  0.5493644  -0.05742672 -0.9244894 ]
# Observation[10]: [ 0.03912424  0.74521306 -0.0759165  -1.2346523 ]
# Observation[10]: [ 0.0540285   0.55114457 -0.10060955 -0.96668604]
# Observation[10]: [ 0.06505139  0.74746321 -0.11994327 -1.28920419]
# Observation[10]: [ 0.08000066  0.94388907 -0.14572735 -1.61690496]
# Observation[10]: [ 0.09887844  0.75075521 -0.17806545 -1.37296719]
# Observation[10]: [ 0.11389354  0.94759961 -0.2055248  -1.71564013]
# Episode finished after 10 timesteps
# Observation[11]: [ 0.02458094 -0.01118002 -0.00726654 -0.00191712]
# Observation[11]: [ 0.02435734 -0.20619701 -0.00730488  0.2884643 ]
# Observation[11]: [ 0.0202334  -0.40121404 -0.0015356   0.57883442]
# Observation[11]: [ 0.01220912 -0.59631443  0.01004109  0.8710332 ]
# Observation[11]: [ 2.82829584e-04 -7.91571506e-01  2.74617573e-02  1.16685608e+00]
# Observation[11]: [-0.0155486  -0.59681747  0.05079888  0.88290791]
# Observation[11]: [-0.02748495 -0.79259115  0.06845704  1.19111806]
# Observation[11]: [-0.04333677 -0.98853004  0.0922794   1.50444864]
# Observation[11]: [-0.06310737 -1.18464259  0.12236837  1.82445751]
# Observation[11]: [-0.08680023 -0.99107275  0.15885752  1.57216051]
# Observation[11]: [-0.10662168 -1.18769333  0.19030073  1.90988573]
# Episode finished after 11 timesteps
# Observation[12]: [ 0.01850999  0.04749667  0.02353891 -0.00873337]
# Observation[12]: [ 0.01945992  0.24227327  0.02336425 -0.29389753]
# Observation[12]: [0.02430539 0.04682614 0.0174863  0.00606162]
# Observation[12]: [ 0.02524191 -0.14854217  0.01760753  0.30420999]
# Observation[12]: [0.02227107 0.04632448 0.02369173 0.01713166]
# Observation[12]: [ 0.02319756  0.2410988   0.02403436 -0.2679831 ]
# Observation[12]: [ 0.02801953  0.43586965  0.0186747  -0.55298957]
# Observation[12]: [ 0.03673692  0.63072444  0.00761491 -0.83973075]
# Observation[12]: [ 0.04935141  0.82574159 -0.00917971 -1.13000925]
# Observation[12]: [ 0.06586625  1.02098255 -0.03177989 -1.42555714]
# Observation[12]: [ 0.0862859   1.21648252 -0.06029103 -1.72800074]
# Observation[12]: [ 0.11061555  1.02209925 -0.09485105 -1.45467043]
# Observation[12]: [ 0.13105753  1.2182491  -0.12394446 -1.77541708]
# Observation[12]: [ 0.15542251  1.02472279 -0.1594528  -1.52370095]
# Observation[12]: [ 0.17591697  0.83184521 -0.18992682 -1.28473549]
# Episode finished after 15 timesteps
# Observation[13]: [-0.02654307 -0.02592297  0.00536275  0.01475212]
# Observation[13]: [-0.02706152 -0.22112142  0.00565779  0.30912222]
# Observation[13]: [-0.03148395 -0.41632352  0.01184023  0.60358408]
# Observation[13]: [-0.03981042 -0.22136916  0.02391192  0.31465397]
# Observation[13]: [-0.04423781 -0.41682342  0.03020499  0.61478099]
# Observation[13]: [-0.05257428 -0.61235411  0.04250061  0.91682215]
# Observation[13]: [-0.06482136 -0.80802416  0.06083706  1.22255361]
# Observation[13]: [-0.08098184 -0.61373644  0.08528813  0.94953625]
# Observation[13]: [-0.09325657 -0.41985974  0.10427885  0.68482257]
# Observation[13]: [-0.10165376 -0.22632828  0.11797531  0.42670477]
# Observation[13]: [-0.10618033 -0.42290634  0.1265094   0.75412656]
# Observation[13]: [-0.11463846 -0.61952429  0.14159193  1.08379117]
# Observation[13]: [-0.12702894 -0.42652546  0.16326776  0.83867912]
# Observation[13]: [-0.13555945 -0.62345527  0.18004134  1.17793326]
# Observation[13]: [-0.14802856 -0.82039935  0.2036      1.521221  ]
# Episode finished after 15 timesteps
# Observation[14]: [-0.03758841  0.01245758 -0.01606172 -0.0423092 ]
# Observation[14]: [-0.03733926  0.20780613 -0.0169079  -0.34001616]
# Observation[14]: [-0.03318313  0.01292879 -0.02370823 -0.05271261]
# Observation[14]: [-0.03292456  0.20838252 -0.02476248 -0.35278039]
# Observation[14]: [-0.02875691  0.01362128 -0.03181809 -0.06800752]
# Observation[14]: [-0.02848448  0.20918462 -0.03317824 -0.37055699]
# Observation[14]: [-0.02430079  0.01454937 -0.04058938 -0.0885174 ]
# Observation[14]: [-0.0240098   0.21022891 -0.04235972 -0.39372496]
# Observation[14]: [-0.01980522  0.01573285 -0.05023422 -0.11469261]
# Observation[14]: [-0.01949057 -0.17863467 -0.05252808  0.16172823]
# Observation[14]: [-0.02306326  0.01719839 -0.04929351 -0.14705234]
# Observation[14]: [-0.02271929 -0.17718428 -0.05223456  0.12968106]
# Observation[14]: [-0.02626298 -0.37152056 -0.04964094  0.40543793]
# Observation[14]: [-0.03369339 -0.5659047  -0.04153218  0.6820665 ]
# Observation[14]: [-0.04501148 -0.76042601 -0.02789085  0.96138991]
# Observation[14]: [-0.06022    -0.56494054 -0.00866305  0.6600769 ]
# Observation[14]: [-0.07151881 -0.75994087  0.00453849  0.95001951]
# Observation[14]: [-0.08671763 -0.5648803   0.02353888  0.65876599]
# Observation[14]: [-0.09801524 -0.76032182  0.0367142   0.95876685]
# Observation[14]: [-0.11322167 -0.95591764  0.05588953  1.2627544 ]
# Observation[14]: [-0.13234003 -1.15170785  0.08114462  1.57240413]
# Observation[14]: [-0.15537418 -1.3476987   0.11259271  1.88925341]
# Observation[14]: [-0.18232816 -1.54384936  0.15037777  2.21464876]
# Observation[14]: [-0.21320514 -1.74005651  0.19467075  2.54968268]
# Episode finished after 24 timesteps
# Observation[15]: [ 0.03783836 -0.01149129 -0.00149713  0.01359641]
# Observation[15]: [ 0.03760854  0.1836521  -0.0012252  -0.2795585 ]
# Observation[15]: [ 0.04128158 -0.01145235 -0.00681637  0.01273775]
# Observation[15]: [ 0.04105253 -0.20647588 -0.00656161  0.30326226]
# Observation[15]: [ 3.69230142e-02 -4.01503709e-01 -4.96367488e-04  5.93868603e-01]
# Observation[15]: [ 0.02889294 -0.59661871  0.011381    0.88639514]
# Observation[15]: [ 0.01696057 -0.79189329  0.02910891  1.18263398]
# Observation[15]: [ 1.12269998e-03 -9.87380641e-01  5.27615869e-02  1.48429759e+00]
# Observation[15]: [-0.01862491 -0.79294018  0.08244754  1.20854748]
# Observation[15]: [-0.03448372 -0.5989742   0.10661849  0.94279895]
# Observation[15]: [-0.0464632  -0.79535865  0.12547447  1.26698939]
# Observation[15]: [-0.06237037 -0.99184011  0.15081426  1.59618736]
# Observation[15]: [-0.08220718 -1.18839421  0.182738    1.9318434 ]
# Episode finished after 13 timesteps
# Observation[16]: [-0.00341219 -0.02520919 -0.04500321  0.00081849]
# Observation[16]: [-0.00391637 -0.2196578  -0.04498684  0.27896962]
# Observation[16]: [-0.00830953 -0.02392392 -0.03940745 -0.02755582]
# Observation[16]: [-0.00878801 -0.21845923 -0.03995857  0.2524378 ]
# Observation[16]: [-0.01315719 -0.4129885  -0.03490981  0.53225409]
# Observation[16]: [-0.02141696 -0.6076025  -0.02426473  0.81373582]
# Observation[16]: [-0.03356901 -0.41215679 -0.00799001  0.51352042]
# Observation[16]: [-0.04181215 -0.21692322  0.0022804   0.21833038]
# Observation[16]: [-0.04615061 -0.02183394  0.006647   -0.07363234]
# Observation[16]: [-0.04658729 -0.21705055  0.00517436  0.22114031]
# Observation[16]: [-0.0509283  -0.41224608  0.00959716  0.51545094]
# Observation[16]: [-0.05917322 -0.60750185  0.01990618  0.81114264]
# Observation[16]: [-0.07132326 -0.41265818  0.03612903  0.52478706]
# Observation[16]: [-0.07957642 -0.2180628   0.04662478  0.24370409]
# Observation[16]: [-0.08393768 -0.02363675  0.05149886 -0.03391533]
# Observation[16]: [-0.08441041 -0.21945794  0.05082055  0.27456101]
# Observation[16]: [-0.08879957 -0.02509654  0.05631177 -0.00166988]
# Observation[16]: [-0.0893015   0.1691745   0.05627837 -0.27606761]
# Observation[16]: [-0.08591801 -0.02670333  0.05075702  0.03382107]
# Observation[16]: [-0.08645208  0.16765539  0.05143344 -0.24242539]
# Observation[16]: [-0.08309897 -0.02816208  0.04658493  0.06602715]
# Observation[16]: [-0.08366221  0.16626209  0.04790548 -0.2116017 ]
# Observation[16]: [-0.08033697  0.36066753  0.04367344 -0.48879649]
# Observation[16]: [-0.07312362  0.16495751  0.03389751 -0.18267547]
# Observation[16]: [-0.06982447  0.35957844  0.030244   -0.4644752 ]
# Observation[16]: [-0.0626329   0.55426025  0.0209545  -0.74747399]
# Observation[16]: [-0.0515477   0.35885557  0.00600502 -0.44827114]
# Observation[16]: [-0.04437059  0.55389206 -0.0029604  -0.73905514]
# Observation[16]: [-0.03329275  0.74905477 -0.0177415  -1.03266827]
# Observation[16]: [-0.01831165  0.94440815 -0.03839487 -1.33086795]
# Observation[16]: [ 5.76513030e-04  1.13999278e+00 -6.50122294e-02 -1.63531400e+00]
# Observation[16]: [ 0.02337637  1.3358145  -0.09771851 -1.9475262 ]
# Observation[16]: [ 0.05009266  1.53183144 -0.13666903 -2.26883245]
# Observation[16]: [ 0.08072929  1.72793852 -0.18204568 -2.60030585]
# Episode finished after 34 timesteps
# Observation[17]: [-0.02517454 -0.03909785  0.0252777  -0.01274014]
# Observation[17]: [-0.02595649  0.15565264  0.02502289 -0.2973417 ]
# Observation[17]: [-0.02284344 -0.03981692  0.01907606  0.00312681]
# Observation[17]: [-0.02363978 -0.23520718  0.0191386   0.30176689]
# Observation[17]: [-0.02834392 -0.04036316  0.02517393  0.01518079]
# Observation[17]: [-0.02915119 -0.23583692  0.02547755  0.31569889]
# Observation[17]: [-0.03386792 -0.43131234  0.03179153  0.61630645]
# Observation[17]: [-0.04249417 -0.23664863  0.04411766  0.33380357]
# Observation[17]: [-0.04722714 -0.43236982  0.05079373  0.64006607]
# Observation[17]: [-0.05587454 -0.23799144  0.06359505  0.36380149]
# Observation[17]: [-0.06063437 -0.04382826  0.07087108  0.0918298 ]
# Observation[17]: [-0.06151093 -0.23989069  0.07270768  0.40600383]
# Observation[17]: [-0.06630875 -0.43596431  0.08082775  0.72069444]
# Observation[17]: [-0.07502803 -0.24204809  0.09524164  0.45450725]
# Observation[17]: [-0.079869   -0.43837861  0.10433179  0.77562709]
# Observation[17]: [-0.08863657 -0.24483457  0.11984433  0.51750758]
# Observation[17]: [-0.09353326 -0.441422    0.13019448  0.84542358]
# Observation[17]: [-0.1023617  -0.63805707  0.14710295  1.17604902]
# Observation[17]: [-0.11512284 -0.44512     0.17062393  0.9328615 ]
# Observation[17]: [-0.12402524 -0.25265968  0.18928116  0.69828349]
# Observation[17]: [-0.12907843 -0.06059593  0.20324683  0.47065029]
# Episode finished after 21 timesteps
# Observation[18]: [-0.03007982  0.0468861   0.01604714  0.01158317]
# Observation[18]: [-0.0291421   0.24177429  0.0162788  -0.27599381]
# Observation[18]: [-0.02430661  0.04642391  0.01075893  0.02177868]
# Observation[18]: [-0.02337813  0.24138993  0.0111945  -0.26749035]
# Observation[18]: [-0.01855034  0.43635034  0.00584469 -0.55662154]
# Observation[18]: [-0.00982333  0.63138975 -0.00528774 -0.84745733]
# Observation[18]: [ 0.00280447  0.82658343 -0.02223688 -1.14179834]
# Observation[18]: [ 0.01933613  1.02198884 -0.04507285 -1.44137109]
# Observation[18]: [ 0.03977591  0.82745    -0.07390027 -1.16310612]
# Observation[18]: [ 0.05632491  1.0234523  -0.09716239 -1.47801404]
# Observation[18]: [ 0.07679396  0.82964176 -0.12672268 -1.21719022]
# Observation[18]: [ 0.09338679  0.63636102 -0.15106648 -0.9667507 ]
# Observation[18]: [ 0.10611401  0.83315333 -0.17040149 -1.30282212]
# Observation[18]: [ 0.12277708  0.6405526  -0.19645794 -1.06796119]
# Episode finished after 14 timesteps
# Observation[19]: [ 0.02137917 -0.03469556 -0.00256579  0.00692187]
# Observation[19]: [ 0.02068526 -0.22978062 -0.00242736  0.29879416]
# Observation[19]: [ 0.01608965 -0.03462415  0.00354853  0.00534667]
# Observation[19]: [ 0.01539716  0.16044673  0.00365546 -0.28621454]
# Observation[19]: [ 0.0186061   0.35551636 -0.00206883 -0.57774232]
# Observation[19]: [ 0.02571642  0.55066725 -0.01362368 -0.87107626]
# Observation[19]: [ 0.03672977  0.35573322 -0.0310452  -0.58270759]
# Observation[19]: [ 0.04384443  0.16105966 -0.04269935 -0.29996378]
# Observation[19]: [ 0.04706563  0.35676339 -0.04869863 -0.60580161]
# Observation[19]: [ 0.0542009   0.16235503 -0.06081466 -0.32884652]
# Observation[19]: [ 0.057448   -0.03185082 -0.06739159 -0.05594477]
# Observation[19]: [ 0.05681098 -0.22594501 -0.06851049  0.2147375 ]
# Observation[19]: [ 0.05229208 -0.42002402 -0.06421574  0.48504674]
# Observation[19]: [ 0.0438916  -0.22405743 -0.0545148   0.17283627]
# Observation[19]: [ 0.03941045 -0.41835848 -0.05105808  0.44783547]
# Observation[19]: [ 0.03104328 -0.6127224  -0.04210137  0.72399686]
# Observation[19]: [ 0.01878883 -0.41704425 -0.02762143  0.41836559]
# Observation[19]: [ 0.01044795 -0.61176412 -0.01925412  0.70221431]
# Observation[19]: [-0.00178733 -0.80661399 -0.00520983  0.98877457]
# Observation[19]: [-0.01791961 -1.00166581  0.01456566  1.27981664]
# Observation[19]: [-0.03795293 -1.19697031  0.04016199  1.57702448]
# Observation[19]: [-0.06189234 -1.00234926  0.07170248  1.29713276]
# Observation[19]: [-0.08193932 -0.80820742  0.09764514  1.02773074]
# Observation[19]: [-0.09810347 -0.6145112   0.11819975  0.7672325 ]
# Observation[19]: [-0.11039369 -0.42119764  0.1335444   0.51395528]
# Observation[19]: [-0.11881765 -0.22818428  0.14382351  0.26615854]
# Observation[19]: [-0.12338133 -0.03537656  0.14914668  0.02207148]
# Observation[19]: [-0.12408886 -0.23228771  0.14958811  0.35784584]
# Observation[19]: [-0.12873462 -0.42918451  0.15674502  0.69370786]
# Observation[19]: [-0.13731831 -0.62609338  0.17061918  1.03134477]
# Observation[19]: [-0.14984018 -0.82302343  0.19124608  1.37236967]
# Episode finished after 31 timesteps

# %%
env = gym.make("CartPole-v0")
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(2)
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
